# %% [markdown]
# ### MaxLyft Proprietary Algorithm
# Written by Adam L. Soubh
# copyright www.website.com
# Confidential and Proprietary
# ***
# * This code was developed to act as the base algorithm for application `MaxLyft`. The `MaxLyft` GUI interface did not materialize, so the application was never completed or released.
# * Input(s)
# * Output(s)

# %%
# This section contains variables for custom user input
# switches/options for adjusting SQUAT DAY movements

# warm ups - must enter all information specifically for movement(s)
sqt_warm_up_movements = ['Monster Walks', 'Band', '3x30ft Each Way', '','']

# beginning squat percentage - week 1
sqt_main_movement = 'Back Squat'
sqt_main_pct = 0.66
# percent squat ramps up each week
sqt_main_pct_ramping = 0.04

# squat day accessory 1
# 8s, 5s, 3s
sqt_accessory_1 = 'Paused Squat'
sqt_accessory_1_start_pct = 0.48
sqt_accessory_1_pct_ramping = 0.02

# squat day accessory 2
# 12s, 10s, 8s, 5s, 3
sqt_accessory_2 = 'RDL'
sqt_accessory_2_start_pct = 0.44
sqt_accessory_2_pct_ramping = 0.02

# squat day accessory 3
sqt_accessory_3 = 'Plank'
sqt_accessory_3_wt = 'BW'

# %%
# pandas used for df manipulation
# os used for manipulating file structure within primary PROGRAM directory
import pandas as pd
import os

# dataframe file with SBD maxes logged (metadata file)
read_in = pd.read_csv('/Users/AdamSoubh/Documents/Code/lifting_code/metadata/maxes.csv', header=0)

# isolate max numbers from metadata file
bench_max = read_in['Bench'][0]
squat_max = read_in['Squat'][0]
deadlift_max = read_in['Deadlift'][0]
ohp_max = read_in['OHP'][0]

# title list for columns on all spreadsheets
column_titles = ['Exercise', 'Weight', 'Reps Scheduled', 'Reps/Weight Achieved', 'RPE']

# %%
# change to main directory for save location of PROGRAM
path_to_main_directory = '/Users/AdamSoubh/Documents/Code/lifting_code/'

# %%
os.makedirs(path_to_main_directory+'PROGRAM/Squat/')

# squat day - week 1
sqt1_top_set = (squat_max*sqt_main_pct)
sqt_accessory_1_wt = (squat_max*sqt_accessory_1_start_pct)
sqt_accessory_2_wt = (deadlift_max*sqt_accessory_2_start_pct)

sqt1 = [sqt_warm_up_movements,
        
        # (top set of squat weight)-0.2(top set of squat weight) rounded to nearest 5
        [sqt_main_movement, 5*round((sqt1_top_set-(0.2*sqt1_top_set))/5), 10, '',''],
             # (top set of squat weight)-0.1(top set of squat weight) rounded to nearest 5    
            ['', 5*round((sqt1_top_set-(0.1*sqt1_top_set))/5), 9, '',''],
             # (top set of squat weight) rounded to nearest 5
            ['', 5*round((sqt1_top_set)/5), 9, '',''],
        
        [sqt_accessory_1, 5*round(sqt_accessory_1_wt/5), '3x8', '',''],
        
        [sqt_accessory_2, 5*round(sqt_accessory_2_wt/5), '3x12', '',''],
        
        [sqt_accessory_3, sqt_accessory_3_wt, '3x0:45', '','']]
        
sqt_wk_1 = pd.DataFrame(sqt1, columns = column_titles)
sqt_wk_1.to_excel('/Users/AdamSoubh/Documents/Code/lifting_code/PROGRAM/Squat/Week_1_squat.xlsx', index=None)

# %%
# squat day - week 2
sqt2_top_set = (squat_max*(sqt_main_pct+sqt_main_pct_ramping))
sqt_accessory_1_wt_wk2 = (squat_max*(sqt_accessory_1_start_pct+sqt_accessory_1_pct_ramping))
sqt_accessory_2_wt_wk2 = (deadlift_max*(sqt_accessory_2_start_pct+sqt_accessory_2_pct_ramping))

sqt2 = [sqt_warm_up_movements,
        
        # (top set of squat weight)-0.2(top set of squat weight) rounded to nearest 5
        [sqt_main_movement, 5*round((sqt2_top_set-(0.2*sqt2_top_set))/5), 10, '',''],
             # (top set of squat weight)-0.1(top set of squat weight) rounded to nearest 5    
            ['', 5*round((sqt2_top_set-(0.1*sqt2_top_set))/5), 8, '',''],
             # (top set of squat weight) rounded to nearest 5
            ['', 5*round((sqt2_top_set)/5), 8, '',''],
        
        [sqt_accessory_1, 5*round(sqt_accessory_1_wt_wk2/5), '3x8', '',''],
        
        [sqt_accessory_2, 5*round(sqt_accessory_2_wt_wk2/5), '3x12', '',''],
        
        [sqt_accessory_3, sqt_accessory_3_wt, '3x0:45', '','']]
        
sqt_wk_2 = pd.DataFrame(sqt2, columns = column_titles)
sqt_wk_2.to_excel('/Users/AdamSoubh/Documents/Code/lifting_code/PROGRAM/Squat/Week_2_squat.xlsx', index=None)

# %%
# squat day - week 3
sqt3_top_set = (squat_max*(sqt_main_pct+(2*sqt_main_pct_ramping)))
sqt_accessory_1_wt_wk3 = (squat_max*(sqt_accessory_1_start_pct+(2*sqt_accessory_1_pct_ramping)))
sqt_accessory_2_wt_wk3 = (deadlift_max*(sqt_accessory_2_start_pct+(2*sqt_accessory_2_pct_ramping)))

sqt3 = [sqt_warm_up_movements,
        
        # (top set of squat weight)-0.3(top set of squat weight) rounded to nearest 5
        [sqt_main_movement, 5*round((sqt3_top_set-(0.3*sqt3_top_set))/5), 10, '',''],
            ['', 5*round((sqt3_top_set-(0.2*sqt3_top_set))/5), 7, '',''],     
            # (top set of squat weight)-0.1(top set of squat weight) rounded to nearest 5    
            ['', 5*round((sqt3_top_set-(0.1*sqt3_top_set))/5), 7, '',''],
             # (top set of squat weight) rounded to nearest 5
            ['', 5*round((sqt3_top_set)/5), 7, '',''],
        
        [sqt_accessory_1, 5*round(sqt_accessory_1_wt_wk3/5), '3x8', '',''],
        
        [sqt_accessory_2, 5*round(sqt_accessory_2_wt_wk3/5), '3x10', '',''],
        
        [sqt_accessory_3, sqt_accessory_3_wt, '3x0:45', '','']]
        
sqt_wk_3 = pd.DataFrame(sqt3, columns = column_titles)
sqt_wk_3.to_excel('/Users/AdamSoubh/Documents/Code/lifting_code/PROGRAM/Squat/Week_3_squat.xlsx', index=None)

# %%
# squat day - week 4
sqt4_top_set = (squat_max*(sqt_main_pct+(3*sqt_main_pct_ramping)))
sqt_accessory_1_wt_wk4 = (squat_max*(sqt_accessory_1_start_pct+(3*sqt_accessory_1_pct_ramping)))
sqt_accessory_2_wt_wk4 = (deadlift_max*(sqt_accessory_2_start_pct+(3*sqt_accessory_2_pct_ramping)))

sqt4 = [sqt_warm_up_movements,
        
        # (top set of squat weight)-0.3(top set of squat weight) rounded to nearest 5
        [sqt_main_movement, 5*round((sqt4_top_set-(0.3*sqt4_top_set))/5), 10, '',''],
            ['', 5*round((sqt4_top_set-(0.2*sqt3_top_set))/5), 6, '',''],     
            # (top set of squat weight)-0.1(top set of squat weight) rounded to nearest 5    
            ['', 5*round((sqt4_top_set-(0.1*sqt3_top_set))/5), 6, '',''],
             # (top set of squat weight) rounded to nearest 5
            ['', 5*round((sqt4_top_set)/5), 6, '',''],
        
        [sqt_accessory_1, 5*round(sqt_accessory_1_wt_wk4/5), '3x5', '',''],
        
        [sqt_accessory_2, 5*round(sqt_accessory_2_wt_wk4/5), '3x10', '',''],
        
        [sqt_accessory_3, sqt_accessory_3_wt, '3x0:45', '','']]
        
sqt_wk_4 = pd.DataFrame(sqt4, columns = column_titles)
sqt_wk_4.to_excel('/Users/AdamSoubh/Documents/Code/lifting_code/PROGRAM/Squat/Week_4_squat.xlsx', index=None)

# %%
# squat day - week 5
sqt5_top_set = (squat_max*(sqt_main_pct+(4*sqt_main_pct_ramping)))
sqt_accessory_1_wt_wk5 = (squat_max*(sqt_accessory_1_start_pct+(4*sqt_accessory_1_pct_ramping)))
sqt_accessory_2_wt_wk5 = (deadlift_max*(sqt_accessory_2_start_pct+(4*sqt_accessory_2_pct_ramping)))

sqt5 = [sqt_warm_up_movements,
        
        # (top set of squat weight)-0.3(top set of squat weight) rounded to nearest 5
        [sqt_main_movement, 5*round((sqt5_top_set-(0.3*sqt5_top_set))/5), 10, '',''],
            ['', 5*round((sqt5_top_set-(0.2*sqt5_top_set))/5), 5, '',''],     
            # (top set of squat weight)-0.1(top set of squat weight) rounded to nearest 5    
            ['', 5*round((sqt5_top_set-(0.1*sqt5_top_set))/5), 5, '',''],
             # (top set of squat weight) rounded to nearest 5
            ['', 5*round((sqt5_top_set)/5), 5, '',''],
        
        [sqt_accessory_1, 5*round(sqt_accessory_1_wt_wk5/5), '3x5', '',''],
        
        [sqt_accessory_2, 5*round(sqt_accessory_2_wt_wk5/5), '3x8', '',''],
        
        [sqt_accessory_3, sqt_accessory_3_wt, '3x0:45', '','']]
        
sqt_wk_5 = pd.DataFrame(sqt5, columns = column_titles)
sqt_wk_5.to_excel('/Users/AdamSoubh/Documents/Code/lifting_code/PROGRAM/Squat/Week_5_squat.xlsx', index=None)

# %%
# squat day - week 6
sqt6_top_set = (squat_max*(sqt_main_pct+(5*sqt_main_pct_ramping)))
sqt_accessory_1_wt_wk6 = (squat_max*(sqt_accessory_1_start_pct+(5*sqt_accessory_1_pct_ramping)))
sqt_accessory_2_wt_wk6 = (deadlift_max*(sqt_accessory_2_start_pct+(5*sqt_accessory_2_pct_ramping)))

sqt6 = [sqt_warm_up_movements,
        
        # (top set of squat weight)-0.4(top set of squat weight) rounded to nearest 5
        [sqt_main_movement, 5*round((sqt6_top_set-(0.4*sqt6_top_set))/5), 10, '',''],
            ['', 5*round((sqt6_top_set-(0.3*sqt6_top_set))/5), 4, '',''],
            ['', 5*round((sqt6_top_set-(0.2*sqt6_top_set))/5), 4, '',''],     
            # (top set of squat weight)-0.1(top set of squat weight) rounded to nearest 5    
            ['', 5*round((sqt6_top_set-(0.1*sqt6_top_set))/5), 4, '',''],
             # (top set of squat weight) rounded to nearest 5
            ['', 5*round((sqt6_top_set)/5), 4, '',''],
        
        [sqt_accessory_1, 5*round(sqt_accessory_1_wt_wk6/5), '3x5', '',''],
        
        [sqt_accessory_2, 5*round(sqt_accessory_2_wt_wk6/5), '3x8', '',''],
        
        [sqt_accessory_3, sqt_accessory_3_wt, '3x0:45', '','']]

sqt_wk_6 = pd.DataFrame(sqt6, columns = column_titles)
sqt_wk_6.to_excel('/Users/AdamSoubh/Documents/Code/lifting_code/PROGRAM/Squat/Week_6_squat.xlsx', index=None)

# %%
# squat day - week 7
sqt7_top_set = (squat_max*(sqt_main_pct+(6*sqt_main_pct_ramping)))
sqt_accessory_1_wt_wk7 = (squat_max*(sqt_accessory_1_start_pct+(6*sqt_accessory_1_pct_ramping)))
sqt_accessory_2_wt_wk7 = (deadlift_max*(sqt_accessory_2_start_pct+(6*sqt_accessory_2_pct_ramping)))

sqt7 = [sqt_warm_up_movements,
        
        # (top set of squat weight)-0.4(top set of squat weight) rounded to nearest 5
        [sqt_main_movement, 5*round((sqt7_top_set-(0.4*sqt7_top_set))/5), 10, '',''],
            ['', 5*round((sqt7_top_set-(0.25*sqt7_top_set))/5), 5, '',''],
            ['', 5*round((sqt7_top_set-(0.15*sqt7_top_set))/5), 3, '',''],     
            # (top set of squat weight)-0.05(top set of squat weight) rounded to nearest 5    
            ['', 5*round((sqt7_top_set-(0.05*sqt7_top_set))/5), 3, '',''],
             # (top set of squat weight) rounded to nearest 5
            ['', 5*round((sqt7_top_set)/5), 3, '',''],
        
        [sqt_accessory_1, 5*round(sqt_accessory_1_wt_wk7/5), '3x3', '',''],
        
        [sqt_accessory_2, 5*round(sqt_accessory_2_wt_wk7/5), '3x5', '',''],
        
        [sqt_accessory_3, sqt_accessory_3_wt, '3x0:45', '','']]

sqt_wk_7 = pd.DataFrame(sqt7, columns = column_titles)
sqt_wk_7.to_excel('/Users/AdamSoubh/Documents/Code/lifting_code/PROGRAM/Squat/Week_7_squat.xlsx', index=None)

# %%
# squat day - week 8
sqt8_top_set = (squat_max*(sqt_main_pct+(7*sqt_main_pct_ramping)))
sqt_accessory_1_wt_wk8 = (squat_max*(sqt_accessory_1_start_pct+(7*sqt_accessory_1_pct_ramping)))
sqt_accessory_2_wt_wk8 = (deadlift_max*(sqt_accessory_2_start_pct+(7*sqt_accessory_2_pct_ramping)))

sqt8 = [sqt_warm_up_movements,
        
        # (top set of squat weight)-0.4(top set of squat weight) rounded to nearest 5
        [sqt_main_movement, 5*round((sqt8_top_set-(0.4*sqt8_top_set))/5), 10, '',''],
            ['', 5*round((sqt8_top_set-(0.25*sqt8_top_set))/5), 5, '',''],
            ['', 5*round((sqt8_top_set-(0.15*sqt8_top_set))/5), 2, '',''],     
            # (top set of squat weight)-0.05(top set of squat weight) rounded to nearest 5    
            ['', 5*round((sqt8_top_set-(0.05*sqt7_top_set))/5), 2, '',''],
             # (top set of squat weight) rounded to nearest 5
            ['', 5*round((sqt8_top_set)/5), 2, '',''],
        
        [sqt_accessory_1, 5*round(sqt_accessory_1_wt_wk8/5), '3x3', '',''],
        
        [sqt_accessory_2, 5*round(sqt_accessory_2_wt_wk8/5), '3x5', '',''],
        
        [sqt_accessory_3, sqt_accessory_3_wt, '3x0:45', '','']]

sqt_wk_8 = pd.DataFrame(sqt8, columns = column_titles)
sqt_wk_8.to_excel('/Users/AdamSoubh/Documents/Code/lifting_code/PROGRAM/Squat/Week_8_squat.xlsx', index=None)

# %%
# squat day - week 9
sqt9_top_set = squat_max
sqt9_top_set_str = (str(squat_max)+str('+'))
sqt_accessory_1_wt_wk9 = (squat_max*(sqt_accessory_1_start_pct+(8*sqt_accessory_1_pct_ramping)))
sqt_accessory_2_wt_wk9 = (deadlift_max*(sqt_accessory_2_start_pct+(8*sqt_accessory_2_pct_ramping)))

sqt9 = [sqt_warm_up_movements,
        
        # (top set of squat weight)-0.4(top set of squat weight) rounded to nearest 5
        [sqt_main_movement, 5*round((sqt9_top_set-(0.4*sqt9_top_set))/5), 10, '',''],
            ['', 5*round((sqt9_top_set-(0.25*sqt9_top_set))/5), 5, '',''],
            ['', 5*round((sqt9_top_set-(0.15*sqt9_top_set))/5), 3, '',''],     
            # (top set of squat weight)-0.05(top set of squat weight) rounded to nearest 5    
            ['', 5*round((sqt9_top_set-(0.05*sqt9_top_set))/5), 1, '',''],
             # (top set of squat weight) rounded to nearest 5
            ['', sqt9_top_set_str, 1, '',''],
        
        [sqt_accessory_1, 5*round(sqt_accessory_1_wt_wk9/5), '2x3', '',''],
        
        [sqt_accessory_2, 5*round(sqt_accessory_2_wt_wk9/5), '2x3', '',''],
        
        [sqt_accessory_3, sqt_accessory_3_wt, '3x0:45', '','']]

sqt_wk_9 = pd.DataFrame(sqt9, columns = column_titles)
sqt_wk_9.to_excel('/Users/AdamSoubh/Documents/Code/lifting_code/PROGRAM/Squat/Week_9_squat.xlsx', index=None)

# %%
# This section contains variables for custom user input
# switches/options for adjusting BENCH DAY movements

# warm ups - must enter all information specifically for movement(s)

# beginning bench percentage - week 1
bench_main_movement = 'Bench Press'
bench_main_pct = 0.63
# percent bench ramps up each week
bench_main_pct_ramping = 0.03

# bench day accessory 1
# 12s, 10s, 8s
bench_accessory_1 = 'Pendlay Row'
# ----- MUST ADD WEIGHT HERE -----
bench_accessory_1_start_weight = 75
bench_accessory_1_ramping_weight = 5

# bench day accessory 2
# 8s, 5s, 3s
bench_accessory_2 = 'Seated OHP'
bench_accessory_2_start_pct = 0.40
bench_accessory_2_pct_ramping = 0.035

# bench day accessory 3
# 8s, 5s
bench_accessory_3 = 'Seated OHP'
bench_accessory_3_start_weight = 30
bench_accessory_3_ramping_weight = 5

# squat day accessory 3
bench_accessory_3 = 'Plank'
bench_accessory_3_wt = 'BW'

# %%
ohp1 = [['Scap Pull Ups', 'BW', '3x5-8', '',''],
        ['Standing OHP', 'weight', '10', '','--'],
            ['', 'weight', '5', '','--'],
            ['', 'weight', '5x10', '',''],
        ['Single Arm Landmine Row', 'weight', '3x12', '',''],
        ['Paused Bench', 'weight', '3x8', '',''],
        ['Tricep Press Downs', 'weight', '90 TOTAL', '--','--']]

ohp_wk_1 = pd.DataFrame(ohp1, columns = column_titles)

bnch1 = [['Chin Ups', 'BW', '3x5-8', '',''],
        ['Paused Bench Press', 'weight', '10', '','--'],
            ['', 'weight', '5', '','--'],
            ['', (bench_max*0.57), '5x10', '',''],
        ['Pendlay Row', 'weight', '3x12', '',''],
        ['Seated OHP', 'weight', '3x8', '',''],
        ['Single Arm Kneeling Landmine Press', 'weight', '2x8', '',''],
        ['Tricep Press Downs', 'weight', '90 TOTAL', '--','--']]

bnch_wk_1 = pd.DataFrame(bnch1, columns = column_titles)
